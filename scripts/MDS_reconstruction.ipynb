# %%
import coffea
from coffea.nanoevents.methods import vector
import coffea.hist as hist
import uproot
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
import sys,os

# from pyjet import cluster
import awkward as ak

from sklearn.cluster import DBSCAN

from coffea.nanoevents import NanoEventsFactory, NanoAODSchema,BaseSchema

sys.path.append(os.getcwd().replace('scripts', 'lib'))
import util

# from numba import jit
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_105/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/coffea/util.py:154: FutureWarning: In coffea version v2023.3.0 (target date: 31 Mar 2023), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Open data files
#
#  * First file contains collision data taken with large MET in the trigger in 2016. This is a sub-set of the analysis nTuple that you will use in the rest of the exercise.
#  * The 2nd file contains signal simulation with $H\rightarrow SS \rightarrow 4b$ events

# %%
fpath = "/eos/uscms/store/user/cmsdas/2026/long_exercises/MDS/data/displacedJetMuon_ntupler.root"
data = NanoEventsFactory.from_root(fpath,
                                   schemaclass=BaseSchema,
                                   treepath="ntuples/llp"
                                  ).events()

fpath ="/eos/uscms/store/user/cmsdas/2026/long_exercises/MDS/signal/displacedJetMuon_ntupler.root"

signal = NanoEventsFactory.from_root(fpath,
                                   schemaclass=BaseSchema,
                                   treepath="ntuples/llp"
                                  ).events()

# %% [markdown]
# ## The tree is loaded with the "coffea" analysis framework
# The events are loaded into an "awkward arrays", i.e. arrays with irregular sizes
# Our event-based data fits into awkward arrays very naturally!
#  - Tree:
#  -  |-muonPt :[ [Pt1,Pt2], [Pt1] ...]
#  -  |-muonEta:[ [Eta1,Eta2], [Eta1] ...]

# %%
# this awkward array has 16965 events, of the type "event"
data
# Out:
# <NanoEventsArray [{isData: True, nPV: 12, ... -666]}] type='16965 * event'>

# %%
# shows the branches of the tree
data.fields
# Out:
# ['isData',
#  'nPV',
#  'runNum',
#  'nSlimmedSecondV',
#  'lumiNum',
#  'eventNum',
#  'eventTime',
#  'pvX',
#  'pvY',
#  'pvZ',
#  'fixedGridRhoAll',
#  'fixedGridRhoFastjetAll',
#  'fixedGridRhoFastjetAllCalo',
#  'fixedGridRhoFastjetCentralCalo',
#  'fixedGridRhoFastjetCentralChargedPileUp',
#  'fixedGridRhoFastjetCentralNeutral',
#  'nPVAll',
#  'pvAllX',
#  'pvAllY',
#  'pvAllZ',
#  'pvAllLogSumPtSq',
#  'pvAllSumPx',
#  'pvAllSumPy',
#  'nBunchXing',
#  'BunchXing',
#  'nPU',
#  'nPUmean',
#  'nMuons',
#  'muonE',
#  'muonPt',
#  'muonEta',
#  'muonPhi',
#  'muonCharge',
#  'muonIsLoose',
#  'muonIsMedium',
#  'muonIsTight',
#  'muon_d0',
#  'muon_dZ',
#  'muon_ip3d',
#  'muon_ip3dSignificance',
#  'muonType',
#  'muonQuality',
#  'muon_pileupIso',
#  'muon_chargedIso',
#  'muon_photonIso',
#  'muon_neutralHadIso',
#  'muon_ptrel',
#  'muon_chargedMiniIso',
#  'muon_photonAndNeutralHadronMiniIso',
#  'muon_chargedPileupMiniIso',
#  'muon_activityMiniIsoAnnulus',
#  'muon_passSingleMuTagFilter',
#  'muon_passHLTFilter',
#  'muon_validFractionTrackerHits',
#  'muon_isGlobal',
#  'muon_normChi2',
#  'muon_chi2LocalPosition',
#  'muon_kinkFinder',
#  'muon_segmentCompatability',
#  'muonIsICHEPMedium',
#  'nElectrons',
#  'eleE',
#  'elePt',
#  'eleEta',
#  'elePhi',
#  'eleCharge',
#  'eleEta_SC',
#  'eleSigmaIetaIeta',
#  'eleFull5x5SigmaIetaIeta',
#  'eleR9',
#  'ele_dEta',
#  'ele_dPhi',
#  'ele_HoverE',
#  'ele_d0',
#  'ele_dZ',
#  'ele_ip3d',
#  'ele_ip3dSignificance',
#  'ele_pileupIso',
#  'ele_chargedIso',
#  'ele_photonIso',
#  'ele_neutralHadIso',
#  'ele_MissHits',
#  'ele_PassConvVeto',
#  'ele_OneOverEminusOneOverP',
#  'ele_IDMVAGeneralPurpose',
#  'ele_IDMVACategoryGeneralPurpose',
#  'ele_IDMVAHZZ',
#  'ele_IDMVACategoryHZZ',
#  'ele_RegressionE',
#  'ele_CombineP4',
#  'ele_ptrel',
#  'ele_chargedMiniIso',
#  'ele_photonAndNeutralHadronMiniIso',
#  'ele_chargedPileupMiniIso',
#  'ele_activityMiniIsoAnnulus',
#  'ele_passSingleEleTagFilter',
#  'ele_passTPOneTagFilter',
#  'ele_passTPTwoTagFilter',
#  'ele_passTPOneProbeFilter',
#  'ele_passTPTwoProbeFilter',
#  'ele_passHLTFilter',
#  'ele_passCutBasedIDVeto',
#  'ele_passCutBasedIDLoose',
#  'ele_passCutBasedIDMedium',
#  'ele_passCutBasedIDTight',
#  'ele_passMVAIsoIDWP80',
#  'ele_passMVAIsoIDWP90',
#  'ele_passMVAIsoIDWP9HZZ',
#  'ele_passMVAIsoIDWPLoose',
#  'ele_passMVANoIsoIDWP80',
#  'ele_passMVANoIsoIDWP90',
#  'ele_passMVANoIsoIDWPLoose',
#  'nTaus',
#  'tauE',
#  'tauPt',
#  'tauEta',
#  'tauPhi',
#  'tau_IsLoose',
#  'tau_IsMedium',
#  'tau_IsTight',
#  'tau_passEleVetoLoose',
#  'tau_passEleVetoMedium',
#  'tau_passEleVetoTight',
#  'tau_passMuVetoLoose',
#  'tau_passMuVetoMedium',
#  'tau_passMuVetoTight',
#  'tau_ID',
#  'tau_combinedIsoDeltaBetaCorr3Hits',
#  'tau_chargedIsoPtSum',
#  'tau_neutralIsoPtSum',
#  'tau_puCorrPtSum',
#  'tau_eleVetoMVA',
#  'tau_eleVetoCategory',
#  'tau_muonVetoMVA',
#  'tau_isoMVAnewDMwLT',
#  'tau_isoMVAnewDMwoLT',
#  'tau_leadCandPt',
#  'tau_leadCandID',
#  'tau_leadChargedHadrCandPt',
#  'tau_leadChargedHadrCandID',
#  'nPFCandidates',
#  'PFCandidatePdgId',
#  'PFCandidatePt',
#  'PFCandidateEta',
#  'PFCandidatePhi',
#  'PFCandidateTrackIndex',
#  'PFCandidatePVIndex',
#  'nPhotons',
#  'nPhotons_overlap',
#  'phoE',
#  'phoPt',
#  'phoEta',
#  'phoPhi',
#  'phoSigmaIetaIeta',
#  'phoFull5x5SigmaIetaIeta',
#  'phoR9',
#  'pho_sminor',
#  'pho_smajor',
#  'pho_HoverE',
#  'pho_sumChargedHadronPtAllVertices',
#  'pho_sumChargedHadronPt',
#  'pho_sumNeutralHadronEt',
#  'pho_sumPhotonEt',
#  'pho_ecalPFClusterIso',
#  'pho_hcalPFClusterIso',
#  'pho_trkSumPtHollowConeDR03',
#  'pho_sumWorstVertexChargedHadronPt',
#  'pho_pfIsoChargedHadronIso',
#  'pho_pfIsoChargedHadronIsoWrongVtx',
#  'pho_pfIsoNeutralHadronIso',
#  'pho_pfIsoPhotonIso',
#  'pho_pfIsoModFrixione',
#  'pho_pfIsoSumPUPt',
#  'pho_isConversion',
#  'pho_passEleVeto',
#  'pho_RegressionE',
#  'pho_RegressionEUncertainty',
#  'pho_IDMVA',
#  'pho_superClusterEnergy',
#  'pho_superClusterRawEnergy',
#  'pho_superClusterEta',
#  'pho_superClusterPhi',
#  'pho_superClusterX',
#  'pho_superClusterY',
#  'pho_superClusterZ',
#  'pho_hasPixelSeed',
#  'pho_passHLTFilter',
#  'pho_passCutBasedIDLoose',
#  'pho_passCutBasedIDMedium',
#  'pho_passCutBasedIDTight',
#  'pho_passMVAIDWP80',
#  'pho_passMVAIDWP90',
#  'pho_convType',
#  'pho_convTrkZ',
#  'pho_convTrkClusZ',
#  'pho_vtxSumPx',
#  'pho_vtxSumPy',
#  'pho_isStandardPhoton',
#  'pho_seedRecHitSwitchToGain6',
#  'pho_seedRecHitSwitchToGain1',
#  'pho_anyRecHitSwitchToGain6',
#  'pho_anyRecHitSwitchToGain1',
#  'nCscWireDigis',
#  'nCscStripDigis',
#  'nCscSeg',
#  'cscSegPhi',
#  'cscSegEta',
#  'cscSegX',
#  'cscSegY',
#  'cscSegZ',
#  'cscSegT',
#  'cscSegChi2',
#  'cscSegChamber',
#  'cscSegStation',
#  'cscSegNRecHits',
#  'ncscRechits',
#  'cscRechitsPhi',
#  'cscRechitsEta',
#  'cscRechitsX',
#  'cscRechitsY',
#  'cscRechitsZ',
#  'cscRechitsE',
#  'cscRechitsTpeak',
#  'cscRechitsTwire',
#  'cscRechitsQuality',
#  'cscRechitsChamber',
#  'cscRechitsStation',
#  'cscRechitsClusterId',
#  'cscRechitsChannels',
#  'cscRechitsNStrips',
#  'cscRechitsHitWire',
#  'cscRechitsWGroupsBX',
#  'cscRechitsNWireGroups',
#  'cscRechitsDetId',
#  'nCscRechitClusters',
#  'cscRechitCluster_match_cscSegCluster_minDeltaR',
#  'cscRechitCluster_match_cscSegCluster_index',
#  'cscRechitCluster_match_gParticle_minDeltaR',
#  'cscRechitCluster_match_gParticle_index',
#  'cscRechitCluster_match_gParticle_id',
#  'cscRechitClusterX',
#  'cscRechitClusterY',
#  'cscRechitClusterZ',
#  'cscRechitClusterTime',
#  'cscRechitClusterTimeTotal',
#  'cscRechitClusterTimeSpread',
#  'cscRechitClusterGenMuonDeltaR',
#  'cscRechitClusterMajorAxis',
#  'cscRechitClusterMinorAxis',
#  'cscRechitClusterEtaPhiSpread',
#  'cscRechitClusterPhiSpread',
#  'cscRechitClusterEtaSpread',
#  'cscRechitClusterXSpread',
#  'cscRechitClusterXYSpread',
#  'cscRechitClusterRSpread',
#  'cscRechitClusterYSpread',
#  'cscRechitClusterZSpread',
#  'cscRechitClusterPhi',
#  'cscRechitClusterEta',
#  'cscRechitClusterJetVetoPt',
#  'cscRechitClusterJetVetoE',
#  'cscRechitClusterMuonVetoPt',
#  'cscRechitClusterMuonVetoE',
#  'cscRechitClusterCaloJetVeto',
#  'cscRechitClusterSize',
#  'cscRechitClusterNRechitChamberPlus11',
#  'cscRechitClusterNRechitChamberPlus12',
#  'cscRechitClusterNRechitChamberPlus13',
#  'cscRechitClusterNRechitChamberPlus21',
#  'cscRechitClusterNRechitChamberPlus22',
#  'cscRechitClusterNRechitChamberPlus31',
#  'cscRechitClusterNRechitChamberPlus32',
#  'cscRechitClusterNRechitChamberPlus41',
#  'cscRechitClusterNRechitChamberPlus42',
#  'cscRechitClusterNRechitChamberMinus11',
#  'cscRechitClusterNRechitChamberMinus12',
#  'cscRechitClusterNRechitChamberMinus13',
#  'cscRechitClusterNRechitChamberMinus21',
#  'cscRechitClusterNRechitChamberMinus22',
#  'cscRechitClusterNRechitChamberMinus31',
#  'cscRechitClusterNRechitChamberMinus32',
#  'cscRechitClusterNRechitChamberMinus41',
#  'cscRechitClusterNRechitChamberMinus42',
#  'cscRechitClusterMe11Ratio',
#  'cscRechitClusterMe12Ratio',
#  'cscRechitClusterNStation',
#  'cscRechitClusterMaxStation',
#  'cscRechitClusterMaxStationRatio',
#  'cscRechitClusterNChamber',
#  'cscRechitClusterMaxChamber',
#  'cscRechitClusterMaxChamberRatio',
#  'cscRechitClusterVertexR',
#  'cscRechitClusterVertexZ',
#  'cscRechitClusterVertexDis',
#  'cscRechitClusterVertexChi2',
#  'cscRechitClusterVertexN1',
#  'cscRechitClusterVertexN5',
#  'cscRechitClusterVertexN10',
#  'cscRechitClusterVertexN15',
#  'cscRechitClusterVertexN20',
#  'cscRechitClusterVertexN',
#  'nCscSegClusters',
#  'cscSegCluster_match_gParticle_minDeltaR',
#  'cscSegCluster_match_gParticle_index',
#  'cscSegCluster_match_gParticle_id',
#  'cscSegClusterX',
#  'cscSegClusterY',
#  'cscSegClusterZ',
#  'cscSegClusterTime',
#  'cscSegClusterTimeSpread',
#  'cscSegClusterGenMuonDeltaR',
#  'cscSegClusterMajorAxis',
#  'cscSegClusterMinorAxis',
#  'cscSegClusterEtaPhiSpread',
#  'cscSegClusterPhiSpread',
#  'cscSegClusterEtaSpread',
#  'cscSegClusterXSpread',
#  'cscSegClusterYSpread',
#  'cscSegClusterZSpread',
#  'cscSegClusterPhi',
#  'cscSegClusterEta',
#  'cscSegClusterJetVetoPt',
#  'cscSegClusterJetVetoE',
#  'cscSegClusterMuonVetoPt',
#  'cscSegClusterMuonVetoE',
#  'cscSegClusterCaloJetVeto',
#  'cscSegClusterSize',
#  'cscSegClusterNSegmentChamberPlus11',
#  'cscSegClusterNSegmentChamberPlus12',
#  'cscSegClusterNSegmentChamberPlus13',
#  'cscSegClusterNSegmentChamberPlus21',
#  'cscSegClusterNSegmentChamberPlus22',
#  'cscSegClusterNSegmentChamberPlus31',
#  'cscSegClusterNSegmentChamberPlus32',
#  'cscSegClusterNSegmentChamberPlus41',
#  'cscSegClusterNSegmentChamberPlus42',
#  'cscSegClusterNSegmentChamberMinus11',
#  'cscSegClusterNSegmentChamberMinus12',
#  'cscSegClusterNSegmentChamberMinus13',
#  'cscSegClusterNSegmentChamberMinus21',
#  'cscSegClusterNSegmentChamberMinus22',
#  'cscSegClusterNSegmentChamberMinus31',
#  'cscSegClusterNSegmentChamberMinus32',
#  'cscSegClusterNSegmentChamberMinus41',
#  'cscSegClusterNSegmentChamberMinus42',
#  'cscSegClusterMe11Ratio',
#  'cscSegClusterMe12Ratio',
#  'cscSegClusterNStation',
#  'cscSegClusterMaxStation',
#  'cscSegClusterMaxStationRatio',
#  'cscSegClusterNChamber',
#  'cscSegClusterMaxChamber',
#  'cscSegClusterMaxChamberRatio',
#  'cscSegClusterVertexR',
#  'cscSegClusterVertexZ',
#  'cscSegClusterVertexDis',
#  'cscSegClusterVertexChi2',
#  'cscSegClusterVertexN1',
#  'cscSegClusterVertexN5',
#  'cscSegClusterVertexN10',
#  'cscSegClusterVertexN15',
#  'cscSegClusterVertexN20',
#  'cscSegClusterVertexN',
#  'nDtRechits',
#  'dtRechitX',
#  'dtRechitY',
#  'dtRechitZ',
#  'dtRechitEta',
#  'dtRechitPhi',
#  'dtRechitTime',
#  'dtRechitStation',
#  'dtRechitWheel',
#  'nDtRechitClusters',
#  'dtRechitCluster_match_gParticle_minDeltaR',
#  'dtRechitCluster_match_gParticle_index',
#  'dtRechitCluster_match_gParticle_id',
#  'dtRechitClusterX',
#  'dtRechitClusterY',
#  'dtRechitClusterZ',
#  'dtRechitClusterTime',
#  'dtRechitClusterTimeSpread',
#  'dtRechitClusterGenMuonDeltaR',
#  'dtRechitClusterMajorAxis',
#  'dtRechitClusterMinorAxis',
#  'dtRechitClusterEtaPhiSpread',
#  'dtRechitClusterPhiSpread',
#  'dtRechitClusterEtaSpread',
#  'dtRechitClusterXSpread',
#  'dtRechitClusterYSpread',
#  'dtRechitClusterZSpread',
#  'dtRechitClusterPhi',
#  'dtRechitClusterEta',
#  'dtRechitClusterJetVetoPt',
#  'dtRechitClusterJetVetoE',
#  'dtRechitClusterMuonVetoPt',
#  'dtRechitClusterMuonVetoE',
#  'dtRechitClusterCaloJetVeto',
#  'dtRechitClusterSize',
#  'dtRechitClusterNStation',
#  'dtRechitClusterMaxStation',
#  'dtRechitClusterMaxStationRatio',
#  'dtRechitClusterNChamber',
#  'dtRechitClusterMaxChamber',
#  'dtRechitClusterMaxChamberRatio',
#  'dtRechitClusterNSegmentStation1',
#  'dtRechitClusterNSegmentStation2',
#  'dtRechitClusterNSegmentStation3',
#  'dtRechitClusterNSegmentStation4',
#  'nRpc',
#  'rpcPhi',
#  'rpcEta',
#  'rpcX',
#  'rpcY',
#  'rpcZ',
#  'rpcT',
#  'rpcBx',
#  'rpcTError',
#  'rpcRegion',
#  'rpcRing',
#  'rpcSector',
#  'rpcStation',
#  'rpcLayer',
#  'nDtSeg',
#  'dtSegPhi',
#  'dtSegEta',
#  'dtSegX',
#  'dtSegY',
#  'dtSegZ',
#  'dtSegStation',
#  'dtSegWheel',
#  'dtSegTime',
#  'dtSegTimeError',
#  'nDtSegClusters',
#  'dtSegCluster_match_gParticle_minDeltaR',
#  'dtSegCluster_match_gParticle_index',
#  'dtSegCluster_match_gParticle_id',
#  'dtSegClusterX',
#  'dtSegClusterY',
#  'dtSegClusterZ',
#  'dtSegClusterTime',
#  'dtSegClusterTimeSpread',
#  'dtSegClusterGenMuonDeltaR',
#  'dtSegClusterMajorAxis',
#  'dtSegClusterMinorAxis',
#  'dtSegClusterEtaPhiSpread',
#  'dtSegClusterPhiSpread',
#  'dtSegClusterEtaSpread',
#  'dtSegClusterXSpread',
#  'dtSegClusterYSpread',
#  'dtSegClusterZSpread',
#  'dtSegClusterPhi',
#  'dtSegClusterEta',
#  'dtSegClusterJetVetoPt',
#  'dtSegClusterJetVetoE',
#  'dtSegClusterMuonVetoPt',
#  'dtSegClusterMuonVetoE',
#  'dtSegClusterCaloJetVeto',
#  'dtSegClusterSize',
#  'dtSegClusterNSegmentStation1',
#  'dtSegClusterNSegmentStation2',
#  'dtSegClusterNSegmentStation3',
#  'dtSegClusterNSegmentStation4',
#  'dtSegClusterNStation',
#  'dtSegClusterMaxStation',
#  'dtSegClusterMaxStationRatio',
#  'dtSegClusterNChamber',
#  'dtSegClusterMaxChamber',
#  'dtSegClusterMaxChamberRatio',
#  'nHORechits',
#  'hoRechit_Eta',
#  'hoRechit_Phi',
#  'hoRechit_E',
#  'hoRechit_X',
#  'hoRechit_Y',
#  'hoRechit_Z',
#  'hoRechit_T',
#  'nRechits',
#  'ecalRechit_Eta',
#  'ecalRechit_Phi',
#  'ecalRechit_E',
#  'ecalRechit_T',
#  'ecalRechit_E_Error',
#  'ecalRechit_T_Error',
#  'ecalRechit_kSaturatedflag',
#  'ecalRechit_kLeadingEdgeRecoveredflag',
#  'ecalRechit_kPoorRecoflag',
#  'ecalRechit_kWeirdflag',
#  'ecalRechit_kDiWeirdflag',
#  'nHBHERechits',
#  'hbheRechit_Eta',
#  'hbheRechit_Phi',
#  'hbheRechit_E',
#  'hbheRechit_X',
#  'hbheRechit_Y',
#  'hbheRechit_Z',
#  'hbheRechit_T',
#  'hbheRechit_iEta',
#  'hbheRechit_iPhi',
#  'hbheRechit_depth',
#  'nTracks',
#  'track_Pt',
#  'track_Eta',
#  'track_Phi',
#  'track_charge',
#  'track_bestVertexIndex',
#  'track_nMissingInnerHits',
#  'track_nMissingOuterHits',
#  'track_nPixelHits',
#  'track_nHits',
#  'track_dxyToBS',
#  'track_dxyErr',
#  'track_dzToPV',
#  'track_dzErr',
#  'track_chi2',
#  'track_ndof',
#  'nJets',
#  'jetE',
#  'jetPt',
#  'jetEta',
#  'jetPhi',
#  'jetCSV',
#  'jetCISV',
#  'jetCMVA',
#  'jetProbb',
#  'jetProbc',
#  'jetProbudsg',
#  'jetProbbb',
#  'jetMass',
#  'jetJetArea',
#  'jetPileupE',
#  'jetPileupId',
#  'jetPileupIdFlag',
#  'jetPassIDLoose',
#  'jetPassIDTight',
#  'jetPassMuFrac',
#  'jetPassEleFrac',
#  'jetPartonFlavor',
#  'jetHadronFlavor',
#  'jetElectronEnergyFraction',
#  'jetPhotonEnergyFraction',
#  'jetChargedHadronEnergyFraction',
#  'jetNeutralHadronEnergyFraction',
#  'jetMuonEnergyFraction',
#  'jetHOEnergyFraction',
#  'jetHFHadronEnergyFraction',
#  'jetHFEMEnergyFraction',
#  'jetChargedHadronMultiplicity',
#  'jetNeutralHadronMultiplicity',
#  'jetPhotonMultiplicity',
#  'jetElectronMultiplicity',
#  'jetMuonMultiplicity',
#  'jetNSV',
#  'jetNSVCand',
#  'jetNVertexTracks',
#  'jetNSelectedTracks',
#  'jetDRSVJet',
#  'jetFlightDist2D',
#  'jetFlightDist2DError',
#  'jetFlightDist3D',
#  'jetFlightDist3DError',
#  'jetSV_x',
#  'jetSV_y',
#  'jetSV_z',
#  'jetSVNTracks',
#  'jetSVMass',
#  'jetAllMuonPt',
#  'jetAllMuonEta',
#  'jetAllMuonPhi',
#  'jetAllMuonM',
#  'jetPtWeightedDZ',
#  'jetNRechits',
#  'jetRechitE',
#  'jetRechitT',
#  'jetRechitT_rms',
#  'jetRechitE_Error',
#  'jetRechitT_Error',
#  'jetAlphaMax',
#  'jetBetaMax',
#  'jetGammaMax_ET',
#  'jetGammaMax_EM',
#  'jetGammaMax_Hadronic',
#  'jetGammaMax',
#  'jetPtAllTracks',
#  'jetPtAllPVTracks',
#  'jetMedianTheta2D',
#  'jetMedianIP',
#  'jetMinDeltaRAllTracks',
#  'jetMinDeltaRPVTracks',
#  'jet_sig_et1',
#  'jet_sig_et2',
#  'jet_energy_frac',
#  'jetAlphaMax_wp',
#  'jetBetaMax_wp',
#  'jetGammaMax_ET_wp',
#  'jetGammaMax_EM_wp',
#  'jetGammaMax_Hadronic_wp',
#  'jetGammaMax_wp',
#  'jetPtAllTracks_wp',
#  'jetPtAllPVTracks_wp',
#  'jetMedianTheta2D_wp',
#  'jetMedianIP_wp',
#  'jetMinDeltaRAllTracks_wp',
#  'jetMinDeltaRPVTracks_wp',
#  'jetNPFCands',
#  'jetPFCandIndex',
#  'nFatJets',
#  'fatJetE',
#  'fatJetPt',
#  'fatJetEta',
#  'fatJetPhi',
#  'fatJetCorrectedPt',
#  'fatJetPrunedM',
#  'fatJetTrimmedM',
#  'fatJetFilteredM',
#  'fatJetSoftDropM',
#  'fatJetCorrectedSoftDropM',
#  'fatJetUncorrectedSoftDropM',
#  'fatJetTau1',
#  'fatJetTau2',
#  'fatJetTau3',
#  'fatJetMaxSubjetCSV',
#  'fatJetPassIDLoose',
#  'fatJetPassIDTight',
#  'fatJetNPFCands',
#  'fatJetPFCandIndex',
#  'metPt',
#  'metPhi',
#  'sumMET',
#  'metUncorrectedPt',
#  'metUncorrectedPhi',
#  'metType1Pt',
#  'metType1Phi',
#  'metPuppiPt',
#  'metPuppiPhi',
#  'metCaloPt',
#  'metCaloPhi',
#  'Flag_HBHENoiseFilter',
#  'Flag_HBHETightNoiseFilter',
#  'Flag_HBHEIsoNoiseFilter',
#  'Flag_badChargedCandidateFilter',
#  'Flag_badMuonFilter',
#  'Flag_badGlobalMuonFilter',
#  'Flag_duplicateMuonFilter',
#  'Flag_globalSuperTightHalo2016Filter',
#  'Flag_globalTightHalo2016Filter',
#  'Flag_hcalLaserEventFilter',
#  'Flag_EcalDeadCellTriggerPrimitiveFilter',
#  'Flag_EcalDeadCellBoundaryEnergyFilter',
#  'Flag_goodVertices',
#  'Flag_trackingFailureFilter',
#  'Flag_eeBadScFilter',
#  'Flag_ecalLaserCorrFilter',
#  'Flag_trkPOGFilters',
#  'Flag_trkPOG_manystripclus53X',
#  'Flag_trkPOG_toomanystripclus53X',
#  'Flag_trkPOG_logErrorTooManyClusters',
#  'Flag_BadPFMuonFilter',
#  'Flag_BadChargedCandidateFilter',
#  'Flag_ecalBadCalibFilter',
#  'Flag_METFilters',
#  'Flag2_globalSuperTightHalo2016Filter',
#  'Flag2_globalTightHalo2016Filter',
#  'Flag2_goodVertices',
#  'Flag2_BadChargedCandidateFilter',
#  'Flag2_BadPFMuonFilter',
#  'Flag2_EcalDeadCellTriggerPrimitiveFilter',
#  'Flag2_HBHENoiseFilter',
#  'Flag2_HBHEIsoNoiseFilter',
#  'Flag2_ecalBadCalibFilter',
#  'Flag2_eeBadScFilter',
#  'HLTDecision',
#  'HLTPrescale',
#  'nGenJets',
#  'genJetE',
#  'genJetPt',
#  'genJetEta',
#  'genJetPhi',
#  'genMetPtCalo',
#  'genMetPhiCalo',
#  'genMetPtTrue',
#  'genMetPhiTrue',
#  'genVertexX',
#  'genVertexY',
#  'genVertexZ',
#  'genVertexT',
#  'genWeight',
#  'genSignalProcessID',
#  'genQScale',
#  'genAlphaQCD',
#  'genAlphaQED',
#  'lheComments',
#  'scaleWeights',
#  'pdfWeights',
#  'alphasWeights',
#  'nGenParticle',
#  'gParticleMotherId',
#  'gParticleMotherIndex',
#  'gParticleId',
#  'gParticleStatus',
#  'gParticleE',
#  'gParticlePt',
#  'gParticleEta',
#  'gParticlePhi',
#  'gParticleProdVertexX',
#  'gParticleProdVertexY',
#  'gParticleProdVertexZ',
#  'gParticleDecayVertexX',
#  'gParticleDecayVertexY',
#  'gParticleDecayVertexZ',
#  'gLLP_decay_vertex_x',
#  'gLLP_decay_vertex_y',
#  'gLLP_decay_vertex_z',
#  'gLLP_beta',
#  'gLLP_e',
#  'gLLP_pt',
#  'gLLP_eta',
#  'gLLP_phi',
#  'gLLP_csc',
#  'gLLP_dt',
#  'gLLP_travel_time',
#  'gLLP_daughter_id',
#  'gLLP_daughter_pt',
#  'gLLP_daughter_eta',
#  'gLLP_daughter_phi',
#  'gLLP_daughter_eta_ecalcorr',
#  'gLLP_daughter_phi_ecalcorr',
#  'gLLP_daughter_e',
#  'gLLP_daughter_mass',
#  'gLLP_grandaughter_id',
#  'gLLP_grandaughter_pt',
#  'gLLP_grandaughter_eta',
#  'gLLP_grandaughter_phi',
#  'gLLP_grandaughter_eta_ecalcorr',
#  'gLLP_grandaughter_phi_ecalcorr',
#  'gLLP_grandaughter_e',
#  'gLLP_grandaughter_mass']

# %% [markdown]
# ## Accessing a branch like this will give the data in the format of (awkward)arrays
#  - Note that the type becomes "int32"
#  - For event-level quantity (number of total rechits),
#    the length of array is the **same** as the number of events

# %%
data.ncscRechits
# Out:
# <Array [41, 56, 25, 10, 64, ... 8, 48, 52, 52] type='16965 * int32[parameters={"...'>

# %% [markdown]
#  - For object-level quantity (X pos. of each rechit), the first dimension of array is the same as the number of events, but the 2nd dimension of the array is **variable (var, float32)**

# %%
data.cscRechitsX
# Out:
# <Array [[116, 116, 116, ... -117, -133, -117]] type='16965 * var * float32[param...'>

# %% [markdown]
# ## Pack all the rechit properties arrays in 1 object

# %%
def pack(events,obj_str):
    obj  = ak.zip(
                {k.replace(obj_str,""):getattr(events,k) for k in events.fields if k.startswith(obj_str)}
                ,with_name="PtEtaPhiMLorentzVector",
                behavior=vector.behavior
               )
    return obj

# %%
rechits = pack(data,"cscRechits")

# %%
d_rechits = rechits
s_rechits = pack(signal,"cscRechits")

# %% [markdown]
#  - These properties mostly follow from the CMSSW definition: [here](https://github.com/cms-sw/cmssw/blob/master/DataFormats/CSCRecHit/interface/CSCRecHit2D.h)
#  - Our nTuplizer only dropped a few properties and computed a few new ones
#  - We will use the following properties:
#    - Eta,Phi
#    - X,Y,Z
#    - Tpeak (Time calculated from strip input), Twire (Time calculated from wire input) [src code](https://github.com/cms-sw/cmssw/blob/master/RecoLocalMuon/CSCRecHitD/src/CSCMake2DRecHit.cc)
#    - Station

# %%
rechits.fields
# Out:
# ['Phi',
#  'Eta',
#  'X',
#  'Y',
#  'Z',
#  'E',
#  'Tpeak',
#  'Twire',
#  'Quality',
#  'Chamber',
#  'Station',
#  'ClusterId',
#  'Channels',
#  'NStrips',
#  'HitWire',
#  'WGroupsBX',
#  'NWireGroups',
#  'DetId']

# %%
# Check number of rechits per event
ak.num(rechits)
# Out:
# <Array [41, 56, 25, 10, 64, ... 8, 48, 52, 52] type='16965 * int64'>

# %% [markdown]
# ## Look at the 2D event display of rechits

# %%
def displayRZ(i_event,rechits=[],cls=[]):
    
    #Select the rechits in the i-th event
    i_rh = rechits[i_event] if len(rechits)>0 else None
    i_cls = cls[i_event] if len(cls)>0 else None
    
    #Make a figure with 2 subplots
    fig, axs = plt.subplots(1,2, figsize=(18,8))

    axs = axs.flatten()
    #plot clusters:
    if len(cls)>0:
        #Eta-phi plot:        
        s1=axs[0].scatter(i_cls.Eta,i_cls.Phi,s=i_cls.Nhit,label="Cluster")
        for cl in i_cls:
            cone = plt.Circle((cl.Eta, cl.Phi), 0.4, color='b', fill=False,)
            axs[0].add_patch(cone)        
        
        #R-Z plot:        
        cls_r = (i_cls.X**2+i_cls.Y**2)**0.5        
        axs[1].scatter(np.abs(i_cls.Z),cls_r,s=i_cls.Nhit)            
    
    #plot rechits:
    if len(rechits)>0:
        #Eta-phi plot:
        s2=axs[0].scatter(i_rh.Eta,i_rh.Phi,s=1,label="Rechits")
        rh_r = (i_rh.X**2+i_rh.Y**2)**0.5    
        
        #R-Z plot:        
        axs[1].scatter(np.abs(i_rh.Z),rh_r,s=1)

    #label eta-phi plot
    axs[0].text(0.1,0.9,"%s-th event"%i_event,transform=axs[0].transAxes)
    axs[0].set_ylim(-np.pi,np.pi)
    axs[0].set_xlim(-5,5)
    axs[0].set_ylabel(r"$\phi$")
    axs[0].set_xlabel(r"$\eta$")
    
    #label RZ plot
    MB_xmin = 300
    util.drawRZ(axs[1],MB_xmin)
    axs[1].set_xlim(MB_xmin,None)
    axs[1].set_xlabel("|z|[cm]")
    axs[1].set_ylabel("R[cm]")
    
    #make legend
    handles, labels = [(a + b) for a, b in zip(axs[0].get_legend_handles_labels(), 
                                           axs[1].get_legend_handles_labels())]
    leg=fig.legend(handles, labels,
                   bbox_to_anchor=(1.0, 1.0), loc='upper left')   
    for ax in axs:
        hep.cms.label(ax=ax,data=True,label="Preliminary")    
    for l in leg.legendHandles:
        l._sizes = [30]
    plt.tight_layout()
    return

# %% [markdown]
# ### Try to look at the rechits from different events!
# Hint: find an event that has a large number of rechits first to get an interesting event!

# %%
# check which events have large number of rechits
np.where(ak.num(rechits)>400)
# Out:
# (<Array [162, 501, 2194, ... 15396, 16922] type='38 * int64'>,)

# %%
plt.style.use(hep.style.CMS) 
displayRZ(2194,rechits)
# Out:
# /tmp/ipykernel_366868/804603489.py:53: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for l in leg.legendHandles:

# %% [markdown]
# # Clustering the rechits
#
# ### First read the discussion in the lesson: [link](https://christinaw97.github.io/MDS_CMSDAS/03-MDS_reco/index.html#clustering-algorithm)
#
# ### Complete the function `computeCluster`, `computeStationProp` and `computeME11_12`
#
# First read the definition of the cluster properties: [here](https://kakwok.github.io/MDS_CMSDAS/03-MDS_reco/index.html#cluster-properties)
#
# Then try to implement them in the relevant functions.
#
# In particular,
#
# ### $\mathrm{avgStation10} = \frac{\sum_i (i \times nhits_i)}{\sum_i nhits_i}$
#
# where `i` sums over the stations with at least 10 hits.

# %% [markdown]
# We are using DBSCAN algorithm, implemented with the python lib: `sklearn.cluster`

# %%
def DBScan(rechits,nCore,eps):
    points=ak.zip([rechits.Eta,rechits.Phi],highlevel=False)

    all_clusters = []
    for x,rechit in zip(points,rechits):
        n_clusters_=0
        core_samples_mask=[]
        ## format into DBSCAN input format x=[ [x1,y1],[x2,y2] ... ]        
        x=np.stack(ak.unzip(x),axis=1)
        i_clusters = []        
        if len(x)>0:            
            db = DBSCAN(eps=eps, min_samples=nCore).fit(x)
            core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
            core_samples_mask[db.core_sample_indices_] = True
            labels = db.labels_    
            n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
            
            ## Loop over clusters in this event
            for iCs in range(n_clusters_):

                #Compute each cluster's properties:
                #    Input = rechits that belongs to this cluster (done via array masking)
                cls = computeCluster(rechit[labels==iCs])
                i_clusters.append(cls)
        all_clusters.append(i_clusters)
    return ak.Array(all_clusters)

# This function compute the cluster properties.
# The input `rechits` is an *array* of rechits used in the cluster  
# This function is ran for each event 
def computeCluster(rechits):
    cls = {}

    cls["Nhit"] = len(rechits)
    cls["Eta"] = np.mean(rechits.Eta)
    cls["Phi"] = np.mean(rechits.Phi)
    cls["X"] = np.mean(rechits.X)
    cls["Y"] = np.mean(rechits.Y)    
    cls["Z"] = np.mean(rechits.Z)        
    cls["Time"]= np.mean((rechits.Tpeak + rechits.Twire)/2)

    avgStation10,nStation10 = computeStationProp(rechits)
    nME11_12 = computeME11_12(rechits)
    
    cls["nStation10"] = nStation10
    cls['avgStation10'] = avgStation10
    cls["nME11_12"] = nME11_12
    
    return cls

# This function compute the cluster properties related to cluster stations.
# The input `rechits` is an *array* of rechits used in the cluster  
# This function is ran for each event 
def computeStationProp(rechits):
    # station can range from -4 to 4   
    uniqueStations = np.array([-4,-3,-2,-1,1,2,3,4])    
    nStation10   = 0
    avgStation10 = 0
    TotHitsStation10 = 0
    for i_station in uniqueStations:
        nRechit_in_i_station = sum(rechits.Station==i_station)
        if nRechit_in_i_station >=10:
            nStation10 +=1
            avgStation10 += i_station * nRechit_in_i_station
            TotHitsStation10 += nRechit_in_i_station
    avgStation10 = avgStation10/TotHitsStation10
    return avgStation10,nStation10

# This function compute the total number of rechits in ME11 and ME12 
# The input `rechits` is an *array* of rechits used in the cluster
# This function is ran for each event 
def computeME11_12(rechits):
    return ak.sum((abs(rechits.Chamber)==11)|(abs(rechits.Chamber)==12))

# %%
# %%time

minPoint = 50
dR = 0.2
cls = DBScan(rechits,minPoint,dR)
# Out:
# CPU times: user 2min 14s, sys: 794 ms, total: 2min 15s
# Wall time: 45.6 s

# %%
d_cls = cls
s_cls = DBScan(s_rechits,minPoint,dR)

# %%
cls.fields
# Out:
# ['Nhit',
#  'Eta',
#  'Phi',
#  'X',
#  'Y',
#  'Z',
#  'Time',
#  'nStation10',
#  'avgStation10',
#  'nME11_12']

# %% [markdown]
# ## Try to see if the cluster in the previous event makes sense!
# Hint: find an event that has a reconstructed cluster first
#
# Do you see a cluster in the event that you chose?

# %%
# check which events have at least 1 cluster
np.where(ak.num(cls)>=1)
# Out:
# (<Array [5, 29, 42, 52, ... 16925, 16957, 16959] type='1515 * int64'>,)

# %%
displayRZ(2194,rechits,cls)
# Out:
# /tmp/ipykernel_366868/804603489.py:53: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for l in leg.legendHandles:

# %% [markdown]
# # Examine cluster properties

# %%
samples=[
    {"cls":d_cls,"label":"data"}, 
    {"cls":s_cls,"label":"signal"},     
]
density=False

# %% [markdown]
# ## Number of clusters and N_rechits

# %%
plt.style.use(hep.style.CMS)  
fig, axs = plt.subplots(1,2,figsize=(16,8))

axs = axs.flatten()
h1= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("nClusters", "nClusters", 10, 0, 10))
h2= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("Nhit", r"$N_{rechit}$", 20, 0, 1000))

for sample in samples:
    cls = sample['cls']
    label = sample['label']
    h1.fill(sample=label ,nClusters=ak.num(cls))
    h2.fill(sample=label ,Nhit = ak.flatten(cls.Nhit))

hist.plot1d(h1,density=density,ax=axs[0])    
hist.plot1d(h2,density=density,ax=axs[1])
for ax in axs:
    
    hep.cms.label(ax=ax,data=True,label="Preliminary")        
    if density: ax.set_ylabel("Density")
plt.tight_layout()

# %% [markdown]
# # Eta, Phi distributions

# %%
plt.style.use(hep.style.CMS)  
fig, axs = plt.subplots(1,2,figsize=(16,8))

axs = axs.flatten()
h1= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("eta", r"$\eta$", 40, -4, 4))
h2= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("phi", "phi", 64, -3.2, 3.2))

for sample in samples:
    cls = sample['cls']
    label = sample['label']
    h1.fill(sample=label ,eta = ak.flatten(cls.Eta))
    h2.fill(sample=label ,phi = ak.flatten(cls.Phi))

hist.plot1d(h1,density=density,ax=axs[0])    
hist.plot1d(h2,density=density,ax=axs[1])
for ax in axs:
    
    hep.cms.label(ax=ax,data=True,label="Preliminary")        
    if density: ax.set_ylabel("Density")
plt.tight_layout()

# %% [markdown]
# # R, Z distributions

# %%
plt.style.use(hep.style.CMS)  
fig, axs = plt.subplots(1,2,figsize=(16,8))

axs = axs.flatten()
h2 = hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("R", "R", 100, 0, 1000))        
h3 = hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("Z", "Z", 120, -1200, 1200))            

for sample in samples:
    cls = sample['cls']
    label = sample['label']
    h2.fill(sample=label ,R = ak.flatten((cls.Y**2+cls.X**2)**0.5))
    h3.fill(sample=label ,Z = ak.flatten(cls.Z))        

hist.plot1d(h2,density=density,ax=axs[0])
hist.plot1d(h3,density=density,ax=axs[1])
for ax in axs:
    
    hep.cms.label(ax=ax,data=True,label="Preliminary")        
    if density: ax.set_ylabel("Density")
plt.tight_layout()

# %% [markdown]
# # Time, nStation10, AvgStation10 distributions

# %%
plt.style.use(hep.style.CMS)  
fig, axs = plt.subplots(1,3,figsize=(24,8))

axs = axs.flatten()
h1= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("Time", 'ClusterTime[ns]',50, -100, 100))                        
h2= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("nStation10", "Nstation10", 8, 0, 8))    
h3= hist.Hist("Events",hist.Cat("sample","sample"),hist.Bin("avgStation10", "AvgStation10", 40, -4, 4))             

for sample in samples:
    cls = sample['cls']
    label = sample['label']
    h1.fill(sample=label ,Time = ak.flatten(cls.Time))
    h2.fill(sample=label ,nStation10 = ak.flatten(cls.nStation10))
    h3.fill(sample=label ,avgStation10 = ak.flatten(cls.avgStation10))    
    

hist.plot1d(h1,density=density,ax=axs[0])    
hist.plot1d(h2,density=density,ax=axs[1])
hist.plot1d(h3,density=density,ax=axs[2])
for ax in axs:
    
    hep.cms.label(ax=ax,data=True,label="Preliminary")        
    if density: ax.set_ylabel("Density")
plt.tight_layout()

# %% [markdown]
# # Bonus: Cluster ID
#
# In the above plot, you should see there's no clear distinction between signal and data in `nStation10` and `Eta`, but some combination of nStation10 and eta may also help us to distinguish between signal and background.
#
# We will use these variable to design a "ClusterID" later.

# %%
h= hist.Hist("Events",
              hist.Bin("nStation10", "Nstation10", 8, 0, 8),
              hist.Bin("eta", r"$\eta$", 40, -3, 3)
             )    
h.fill(nStation10=ak.flatten(cls.nStation10),
      eta = ak.flatten(cls.Eta))
h_group = h.group("nStation10",hist.Cat("nStationGrp","nStationGrp"),
                 {
                     "nStation=1":slice(0,2),
                     "nStation>=1":slice(2,None),                     
                 })

# %%
hist.plot1d(h_group,density=True)
# Out:
# <Axes: xlabel='$\\eta$', ylabel='Events'>

# %%
h.to_hist().project("eta","nStation10").plot2d_full()
# Out:
# (ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f1a6c50bac0>, cbar=None, text=[]),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f1a6c4ef880>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)],
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f1a6c497190>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])

# %% [markdown]
# # MDS reconstruction efficiency for signal

# %% [markdown]
# When an LLP decay in CSC, we want to know
#  - *how often* it can make an MDS cluster (this is cluster efficiency) and
#  - where does the LLP decay when this happens
#
# In this part, we will make a plot of MDS efficiency as a function LLP decay position and try to understand it.

# %% [markdown]
# # load a signal ntuple
#
# In this ntuple, the DBSCAN algorithm is already performed to reconstruct clusters from rechits, so only clusters and the cluster properties that you've seen in the previous exercise are stored

# %%
fpath ="/eos/uscms/store/user/cmsdas/2026/long_exercises/MDS/signal/nocuts/ggH_HToSSTobbbb_MH-125_MS-40_ctau-1000_137000pb_weighted.root"

signal = NanoEventsFactory.from_root(fpath,
                                   schemaclass=BaseSchema,
                                   treepath="MuonSystem"
                                  ).events()

# %%
signal
# Out:
# <NanoEventsArray [{runNum: 1, ... METTrigger: False}] type='6916000 * event'>

# %% [markdown]
# # Selections
# Here we will select for events that have only one LLP decaying in the CSCs and calculate the probabilty of a cluster being reconstructed given that an LLP decayed in the CSC.
# You will use the following branches:
# * `gLLP_csc`: Boolean, a LLP-level variable that tells you whether an LLP decayed in CSC
# * `gLLP_decay_vertex_z`: LLP-level variable that returns LLP lab frame decay vertex in Z [cm]
# * `cscRechitCluster_match_gLLP_csc`: Boolean, cluster-level variable that returns true of the cluster is matched to an LLP ($\Delta R (cluster, LLP) < 0.4$) that decayed in CSC
# * `cscRechitCluster_match_gLLP_decay_z`: float, cluster-level variable that returns the LLP decay vertex in z if its matched to an LLP

# %% [markdown]
# ## Ex: Denominator selection
#
# We will select events with only 1 LLP decaying in CSC.
#
# There are 2 LLPs in each events.
#
# Compute the number of LLP that decays in the CSC first, then make a selection mask
#
# How many events are there?
#
# This will be the denominator of your signal efficiency.

# %%
nLLPinCSC = ak.sum(signal.gLLP_csc,axis=1)

# %%
# There are 2 conditions:
# - Only 1 LLP in CSC [This is an event level selection]
# - the LLP needs in CSC [This is an object level selection]
#  We need this condition because we will be applying this mask on obj. level array

denom_sel = (nLLPinCSC==1)&(signal.gLLP_csc==1)

# %%
print("Events with 1 LLP decaying in CSC: ", ak.sum(denom_sel))
print("Total generated signal events ", len(signal))
print("Acceptance in CSC ", ak.sum(denom_sel)/len(signal))
# Out:
# Events with 1 LLP decaying in CSC:  1075912
# Total generated signal events  6916000
# Acceptance in CSC  0.15556853672643145

# %%
# z coordinates of the LLP in the denominator
# we sum over the LLPs in the event axis(axis=1) [which there is only 1 LLP]
llp_z = ak.sum(abs(signal.gLLP_decay_vertex_z[denom_sel]),axis=1)

# %% [markdown]
# ## Ex: Numerator selection
#
# Select events with only 1 cluster AND in the denominator.
#
# Among those events, select the ones that there's one cluster matched to the LLP.

# %%
nClsInCSC = ak.sum(signal.cscRechitCluster_match_gLLP_csc,axis=1)

# %%
# There are 3 conditions:
# - Only 1 cluster in CSC [This is an event level selection]
# - Only 1 LLP in CSC     [This is an event level selection]
# - the cluster needs to be matched to the LLP [This is an object(cluster) level selection]
#  We need this condition because we will be applying this mask on obj. level array

numer_sel = (nClsInCSC==1) & (nLLPinCSC==1) & (signal.cscRechitCluster_match_gLLP_csc==1)

# %%
# z coordinates of the LLP in the numerator
# we sum over the clusters in the event axis(axis=1)[which there is only 1 cls]
cls_z = ak.sum(abs(signal.cscRechitCluster_match_gLLP_decay_z[numer_sel]),axis=1)

# %% [markdown]
# ## EX: Inclusive efficiency
#
# What is the overall efficiency of reconstructing an MDS cluster of 50 hits for this signal?

# %%
print("Events with 1 LLP decaying in CSC: ", ak.sum(denom_sel))
print("Events with 1 LLP decaying in CSC and a cluster matched to LLP: ", ak.sum(numer_sel))
print("Inclusive efficiency = %.2f"%(ak.sum(numer_sel)/ak.sum(denom_sel)))
# Out:
# Events with 1 LLP decaying in CSC:  1075912
# Events with 1 LLP decaying in CSC and a cluster matched to LLP:  628077
# Inclusive efficiency = 0.58

# %% [markdown]
# # Fill the histogram

# %% [markdown]
# This is an **example** of filling a histogram with a `category` axis (for different samples),
#
# and a `Bin` axis for storing the values.
#
# This is a compact way of handling the histograms.
#
# You will use this type of histograms later on in the exercise.
#
# Which varaible should we fill-in in the function?

# %%
#Create a 2D histogram with a "sample" axis and an axis
hz= hist.Hist("Events",
              hist.Cat("sample","sample"), 
              hist.Bin("z", "LLP decay Z[cm]", 35, 400, 1075)
             )

#Fill the LLP decay position in CSC in the denominator bin
hz.fill(sample="denom", z=llp_z)
#Fill the LLP decay position in CSC matched to a cluster in the numerator bin
hz.fill(sample="numer", z=cls_z)

# %% [markdown]
# # Efficiency v.s. decay position

# %% [markdown]
# We will plot the cluster reconstruction efficiency with repect to the LLP decay position and overlay the steel region in the plot.
#
# Here's a function to draw the CSC steel region.

# %%
## A function to draw the CSC steel region
import matplotlib.patches as patches

def drawCSCz(ax):
    ax.set_xlim(350,1150)
    (xmin,xmax) = ax.get_xlim()

    xmin = 350
    y_max = ax.get_ylim()[1]

    preME11 = patches.Rectangle((xmin, 0), 568-xmin, 2,color='grey',alpha=0.3)
    ME11_12 = patches.Rectangle((632, 0), 39, 2,color='grey',alpha=0.3)
    ME12_2  = patches.Rectangle((724, 0), 65, 2,color='grey',alpha=0.3)
    ME2_3   = patches.Rectangle((849, 0), 62, 2,color='grey',alpha=0.3)
    ME3_4   = patches.Rectangle((970, 0), 32, 2,color='grey',alpha=0.3)
    beyond  = patches.Rectangle((1075, 0),150, 2,color='grey',alpha=0.3)

    ax.text(570*1.045, y_max*1.02, 'ME1/1', fontsize=16,rotation=90,weight='bold')
    ax.text(670*1.02, y_max*1.02, 'ME1/2-3', fontsize=16,rotation=90,weight='bold')
    ax.text(800, y_max*1.02, 'ME2', fontsize=16,rotation=90,weight='bold')
    ax.text(920, y_max*1.02, 'ME3', fontsize=16,rotation=90,weight='bold')
    ax.text(1015, y_max*1.02,'ME4', fontsize=16,rotation=90,weight='bold')
    ax.text(xmin+15 ,y_max*0.5, "Steel", fontsize=26,rotation=90,weight='bold')
    ax.text(xmax-20,y_max*0.5, "Beyond CMS", fontsize=26,rotation=90,weight='bold')

    ax.add_patch(preME11)
    ax.add_patch(ME11_12)
    ax.add_patch(ME12_2)
    ax.add_patch(ME2_3)
    ax.add_patch(ME3_4)
    ax.add_patch(beyond)
    return ax

# %% [markdown]
# ## Plotting the efficiency
#
# We can obtain the 1D histogram by integrating the `numer`/`denom` bin in the 2D histogram.
#
# e.g. `hz.integrate("sample",'numer')` will return a 1D histogram with only the numerator content.

# %%
plt.style.use(hep.style.CMS)  
fig, ax = plt.subplots(1,1,figsize=(12,9))

# We use the "clopper-pearson" 
# Have a read of what it's doing here (the "efficiency" option): 
# https://hist.readthedocs.io/en/latest/reference/hist.intervals.html#hist.intervals.ratio_uncertainty

hist.plotratio(num=hz.integrate("sample",'numer'),
               denom=hz.integrate("sample",'denom'),xerr=True,
               error_opts={"linestyle":'none',"lw":4},ax=ax,
               unc = "clopper-pearson"
               )

ax.set_ylabel("Cluster Efficiency")
ax.set_xlabel("LLP z decay position [cm]")

ax=drawCSCz(ax)
ax.set_ylim(0,1)
ax.set_xlim(350,1150)
ax.grid() 
hep.cms.label(ax=ax,com=13)
plt.tight_layout()

# %% [markdown]
# # Ex: Plot the 2D histogram of LLP and cluster positions
#
# - Why does the efficiency drops off at the two ends of the muon detectors?
# - How does the efficiency varies between the muon stations? Do you understand why?
# - Make a 2D histogram to confirm your understanding!

# %%
hz= hist.Hist("Events", 
              hist.Bin("z_llp", "LLP decay Z[cm]", 35, 400, 1075),
              hist.Bin("z_cls", "Cluster Z[cm]", 35, 400, 1075)              
             )
# Plot the LLP decay position in CSC
llp_z = ak.sum(abs(signal.gLLP_decay_vertex_z[denom_sel]),axis=1)

# Plot the position of the matched cluster in z
# - Get the cluster Z position
# - Apply the numerator selection you computed above
cls_z = ak.sum(abs(signal.cscRechitClusterZ[numer_sel]),axis=1)


hz.fill(z_llp=llp_z, z_cls = cls_z)

# %%
hist.plot2d(hz,xaxis="z_llp")
# Out:
# <Axes: xlabel='LLP decay Z[cm]', ylabel='Cluster Z[cm]'>
